# %%
pip install spotipy
# Out:
# ...
#    ---------------------------------------- 0.0/250.3 kB ? eta -:--:--
#    ------ --------------------------------- 41.0/250.3 kB 2.0 MB/s eta 0:00:01
#    -------------------------------- ------- 204.8/250.3 kB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 250.3/250.3 kB 2.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id ="59e1b7c030fa434db12972b9b1e7eb04" , client_secret ="31873934a0624bf2a29315621f152e4f")

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlist_url ="https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF"

# %%
playlist_url.split('/')
# Out:
# ['https:', '', 'open.spotify.com', 'playlist', '37i9dQZEVXbMDoHDwVN2tF']

# %%
playlist_uri = playlist_url.split('/')[-1]
playlist_uri
# Out:
# '37i9dQZEVXbMDoHDwVN2tF'

# %%
sp.playlist_tracks(playlist_uri)                                            #In spotify api, there is this library 'playlist_tracks' which we are using as per our needs
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbMDoHDwVN2tF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-02-22T10:08:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22wbnEMDvgVIAGdFeek6ET'},
#        'href': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET',
#        'id': '22wbnEMDvgVIAGdFeek6ET',
#        'name': 'Benson Boone',
#        'type': 'artist',
#        'uri': 'spotify:artist:22wbnEMDvgVIAGdFeek6ET'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
# ...

# %%
data = sp.playlist_tracks(playlist_uri)

# %%
playlists = sp.user_playlists('spotify')                   #I have put this statement all code be run on this page, and I don't know what
                                                             #  is the use of thsi code
playlists
# Out:
# {'href': 'https://api.spotify.com/v1/users/spotify/playlists?offset=0&limit=50',
#  'items': [{'collaborative': False,
#    'description': 'Beyoncé is on top of the Hottest 50!',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcBWIGoYBM5M'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M',
#    'id': '37i9dQZF1DXcBWIGoYBM5M',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f000000034fea192e4badc04a095e1152',
#      'width': None}],
#    'name': 'Today’s Top Hits',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTcwODY2NDQwMCwwMDAwMDAwMGE1NzBhYjA4N2I5NTFkNWIyMWMxNDE1MGE4MDM2ZTY0',
# ...

# %% [markdown]
# # We will transform data in 3 useful tables

# %%
data['items'][0]
# Out:
# {'added_at': '2024-02-22T10:08:45Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22wbnEMDvgVIAGdFeek6ET'},
#      'href': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET',
#      'id': '22wbnEMDvgVIAGdFeek6ET',
#      'name': 'Benson Boone',
#      'type': 'artist',
#      'uri': 'spotify:artist:22wbnEMDvgVIAGdFeek6ET'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
# ...

# %%
len(data['items'])
# Out:
# 50

# %%
data['items'][0]['track']['album']['id']
# Out:
# '29aSKB1qPEbN0Qf9OPSQpw'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Beautiful Things'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-01-18'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/29aSKB1qPEbN0Qf9OPSQpw'

# %% [markdown]
# # We can extract more columns for the table
# ## but for now we have enough details for the purpose of
# # ALBUM LIST #1

# %%
album_list= []
#To store the elements from the album elements after every set period of time, we have got this
                                                 # list made in order to collect the dict that we are making after perfoming what is done below

for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_elements = {'album_id': album_id, 'album_name': album_name, 'album_release_date': album_release_date, 
                      'album_total_tracks': album_total_tracks, 'album_url': album_url}   
    
    
    album_list.append(album_elements)

# %%
album_list
# Out:
# [{'album_id': '29aSKB1qPEbN0Qf9OPSQpw',
#   'album_name': 'Beautiful Things',
#   'album_release_date': '2024-01-18',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/29aSKB1qPEbN0Qf9OPSQpw'},
#  {'album_id': '2NXwHjhgaAdkDy6GPSxMAd',
#   'album_name': "TEXAS HOLD 'EM",
#   'album_release_date': '2024-02-10',
#   'album_total_tracks': 3,
#   'album_url': 'https://open.spotify.com/album/2NXwHjhgaAdkDy6GPSxMAd'},
#  {'album_id': '30zwjSQEodaUXCn11nmiVF',
#   'album_name': 'VULTURES 1',
#   'album_release_date': '2024-02-09',
#   'album_total_tracks': 16,
#   'album_url': 'https://open.spotify.com/album/30zwjSQEodaUXCn11nmiVF'},
#  {'album_id': '3UOV8XvCwMKaATRNXrYCjN',
#   'album_name': 'greedy',
#   'album_release_date': '2023-09-15',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/3UOV8XvCwMKaATRNXrYCjN'},
#  {'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'album_name': 'Lover',
#   'album_release_date': '2019-08-23',
# ...

# %%
print(len(album_list))
# Out:
# 50

# %% [markdown]
# # We can make a list for the 2 table purpose ie, SONG ARTIST

# %%
data['items'][0]['track']['artists'][0]['name']
# Out:
# 'Benson Boone'

# %%
data['items'][0]['track']
# Out:
# {'added_at': '2024-02-22T10:08:45Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22wbnEMDvgVIAGdFeek6ET'},
#      'href': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET',
#      'id': '22wbnEMDvgVIAGdFeek6ET',
#      'name': 'Benson Boone',
#      'type': 'artist',
#      'uri': 'spotify:artist:22wbnEMDvgVIAGdFeek6ET'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
# ...

# %% [markdown]
# # We are going to loop in do get our required artist info
# ## in dict form and then finally append it while looping to make it all in one list

# %% [markdown]
# ##### TESTING PHASE 1

# %%
for row in data['items']:
    for key, value in row.items():                             #The items () method in the dictionary is used to return each item in
                                                                # a dictionary as tuples in a list.
        print(value)
# Out:
# 2024-02-22T10:08:45Z
# {'external_urls': {'spotify': 'https://open.spotify.com/user/'}, 'href': 'https://api.spotify.com/v1/users/', 'id': '', 'type': 'user', 'uri': 'spotify:user:'}
# False
# None
# ...

# %% [markdown]
# ##### TESTING PHASE 2

# %%
for row in data['items']:
    for key, value in row.items():                             #The items () method in the dictionary is used to return each item in
                                                                # a dictionary as tuples in a list.
        if key == 'track':
            print(value)
# Out:
# {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22wbnEMDvgVIAGdFeek6ET'}, 'href': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET', 'id': '22wbnEMDvgVIAGdFeek6ET', 'name': 'Benson Boone', 'type': 'artist', 'uri': 'spotify:artist:22wbnEMDvgVIAGdFeek6ET'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW',
# ...

# %% [markdown]
# ##### TESTING PHASE 3

# %%
for row in data['items']:
    for key, value in row.items():                          #The items () method in the dictionary is used to return each item in
                                                                # a dictionary as tuples in a list.
        if key == 'track':
            for artist in value['artists']:
                print(artist)
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/22wbnEMDvgVIAGdFeek6ET'}, 'href': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET', 'id': '22wbnEMDvgVIAGdFeek6ET', 'name': 'Benson Boone', 'type': 'artist', 'uri': 'spotify:artist:22wbnEMDvgVIAGdFeek6ET'}
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'}, 'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m', 'id': '6vWDO969PvNqNYHIOW5v0m', 'name': 'Beyoncé', 'type': 'artist', 'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4xPQFgDA5M2xa0ZGo5iIsv'}, 'href': 'https://api.spotify.com/v1/artists/4xPQFgDA5M2xa0ZGo5iIsv', 'id': '4xPQFgDA5M2xa0ZGo5iIsv', 'name': '¥$', 'type': 'artist', 'uri': 'spotify:artist:4xPQFgDA5M2xa0ZGo5iIsv'}
# ...

# %% [markdown]
# ##### Final TESTING STEP

# %%
for row in data['items']:
    for key, value in row.items():                          #The items () method in the dictionary is used to return each item in
                                                                # a dictionary as tuples in a list.
        if key == 'track':
            for artist in value['artists']:
                print(artist['id'])
# Out:
# 22wbnEMDvgVIAGdFeek6ET
# 6vWDO969PvNqNYHIOW5v0m
# 4xPQFgDA5M2xa0ZGo5iIsv
# 5K4W6rqBFWDnAN6FQUkS6x
# 7c0XG5cIJTrrAgEC3ULPiq
# 45dkTj5sMRSjrmBSBeiHym
# 06HL4z0CvFAxyc27GXpf02
# 3Me35AWHCGqW4sZ7bWWJt1
# 1Xyo4u8uXC1ZmMpatF05PJ
# 250b0Wlc5Vk0CoUsaCY84M
# 1pBLC0qVRTB5zVMuteQ9jJ
# 33qOK5uJ8AR2xuQQAhHump
# 2RQXRUsr4IW1f3mKyKsy4B
# 2uYWxilOVlUdk4oV9DvwqK
# 1URnnhqYAYcrqrcwql10ft
# 0n4Fao9kbjgM76RmVlfSwr
# 2LRoIwlKmHjgvigdNGBHNo
# 7jAs1uPnpfNmT6e5qtEPxq
# 6M2wZ9GZgrQXHCFfjv46we
# 2LIk90788K0zvyj2JJVwkJ
# 7o95ZoZt5ZYn31e9z1Hc0a
# 3Me35AWHCGqW4sZ7bWWJt1
# 5p9HO3XC5P3BLxJs5Mtrhm
# 7Ln80lUS6He07XvHI8qqHH
# 6M2wZ9GZgrQXHCFfjv46we
# 66CXWjxzNUsdJxJ2JdwvnR
# 1Xyo4u8uXC1ZmMpatF05PJ
# 699OTQXzgjhIYAHMy9RyPD
# 6tbjWDEIzxoDsBA1FuhfPW
# 5YGY8feqx7naU7z4HrwZM6
# 4q3ewBCX7sLwd24euuV69X
# 2LRoIwlKmHjgvigdNGBHNo
# 6HaGTQPmzraVmaVxvz6EUc
# 3MdXrJWsbVzdn6fe5JYkSQ
# 7iK8PXO48WeuP03g8YR51W
# 6ltzsmQQbmdoHHbLZ4ZN25
# 790FomKkXshlbRYZFtlgla
# 12GqGscKJx3aE4t07u7eVZ
# 7tYKF4w9nC0nq9CsPZTHyP
# 7uMDnSZyUYNBPLhPMNuaM2
# ...

# %% [markdown]
# # the ARTIST LIST #2

# %%
#Making a list to hold all the data after performing all the action that is happening under this
artist_list = []

for row in data['items']:
    for key, value in row.items():                          #The items () method in the dictionary is used to return each item in
                                                                # a dictionary as tuples in a list.
        if key == 'track':
            for artist in value['artists']:
                                               #Now making a dict from all this data retrieved
                artist_dict = {'artist_id': artist['id'], 'artist_name': artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '22wbnEMDvgVIAGdFeek6ET',
#   'artist_name': 'Benson Boone',
#   'external_url': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET'},
#  {'artist_id': '6vWDO969PvNqNYHIOW5v0m',
#   'artist_name': 'Beyoncé',
#   'external_url': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m'},
#  {'artist_id': '4xPQFgDA5M2xa0ZGo5iIsv',
#   'artist_name': '¥$',
#   'external_url': 'https://api.spotify.com/v1/artists/4xPQFgDA5M2xa0ZGo5iIsv'},
#  {'artist_id': '5K4W6rqBFWDnAN6FQUkS6x',
#   'artist_name': 'Kanye West',
#   'external_url': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x'},
#  {'artist_id': '7c0XG5cIJTrrAgEC3ULPiq',
#   'artist_name': 'Ty Dolla $ign',
#   'external_url': 'https://api.spotify.com/v1/artists/7c0XG5cIJTrrAgEC3ULPiq'},
#  {'artist_id': '45dkTj5sMRSjrmBSBeiHym',
#   'artist_name': 'Tate McRae',
#   'external_url': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
# ...

# %% [markdown]
# ### Now for the last table that we have to form
# # SONG LIST #3

# %% [markdown]
# ##### Just the general way of get through and accessing the data required

# %%
data['items'][0]['track']
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22wbnEMDvgVIAGdFeek6ET'},
#     'href': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET',
#     'id': '22wbnEMDvgVIAGdFeek6ET',
#     'name': 'Benson Boone',
#     'type': 'artist',
#     'uri': 'spotify:artist:22wbnEMDvgVIAGdFeek6ET'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
# ...

# %%
song_list= []

for row in data['items']:
    song_id= row['track']['id']
    song_name= row['track']['name']
    song_duration= row['track']['duration_ms']
    song_url= row['track']['external_urls']['spotify']
    song_popularity= row['track']['popularity']
    song_added= row['added_at']
    album_id= row['track']['album']['id']
    song_id= row['track']['id']
    artist_id= row['track']['album']['artists'][0]['id']

     #making a dict to assemble these all in one place
    song_element= {'song_id': song_id, 'song_name': song_name, 'duration_ms': song_duration, 'url': song_url,
                  'popularity': song_popularity, 'song_added': song_added, 'album_id': album_id,
                   'artist_id': artist_id}
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '6tNQ70jh4OwmPGpYy6R2o9',
#   'song_name': 'Beautiful Things',
#   'duration_ms': 180304,
#   'url': 'https://open.spotify.com/track/6tNQ70jh4OwmPGpYy6R2o9',
#   'popularity': 98,
#   'song_added': '2024-02-22T10:08:45Z',
#   'album_id': '29aSKB1qPEbN0Qf9OPSQpw',
#   'artist_id': '22wbnEMDvgVIAGdFeek6ET'},
#  {'song_id': '7AYmToZ5y67fBjq4RLFbuq',
#   'song_name': "TEXAS HOLD 'EM",
#   'duration_ms': 235636,
#   'url': 'https://open.spotify.com/track/7AYmToZ5y67fBjq4RLFbuq',
#   'popularity': 77,
#   'song_added': '2024-02-22T10:08:45Z',
#   'album_id': '2NXwHjhgaAdkDy6GPSxMAd',
#   'artist_id': '6vWDO969PvNqNYHIOW5v0m'},
#  {'song_id': '3w0w2T288dec0mgeZZqoNN',
#   'song_name': 'CARNIVAL',
#   'duration_ms': 264324,
#   'url': 'https://open.spotify.com/track/3w0w2T288dec0mgeZZqoNN',
#   'popularity': 88,
#   'song_added': '2024-02-22T10:08:45Z',
#   'album_id': '30zwjSQEodaUXCn11nmiVF',
#   'artist_id': '4xPQFgDA5M2xa0ZGo5iIsv'},
#  {'song_id': '3rUGC1vUpkDG9CZFHMur1t',
# ...

# %% [markdown]
# ## So we have made the three lists that we wanted

# %% [markdown]
# # Converting lists of DataFrames

# %%
import pandas as pd

# %% [markdown]
# ### ALBUM DF

# %%
album_df = pd.DataFrame.from_dict(album_list)
album_df.head()
# Out:
#                  album_id        album_name album_release_date  \
# 0  29aSKB1qPEbN0Qf9OPSQpw  Beautiful Things         2024-01-18
# 1  2NXwHjhgaAdkDy6GPSxMAd    TEXAS HOLD 'EM         2024-02-10
# 2  30zwjSQEodaUXCn11nmiVF        VULTURES 1         2024-02-09
# 3  3UOV8XvCwMKaATRNXrYCjN            greedy         2023-09-15
# 4  1NAmidJlEaVgA3MpcPFYGq             Lover         2019-08-23
#
#    album_total_tracks                                          album_url
# 0                   1  https://open.spotify.com/album/29aSKB1qPEbN0Qf...
# 1                   3  https://open.spotify.com/album/2NXwHjhgaAdkDy6...
# 2                  16  https://open.spotify.com/album/30zwjSQEodaUXCn...
# 3                   1  https://open.spotify.com/album/3UOV8XvCwMKaATR...
# 4                  18  https://open.spotify.com/album/1NAmidJlEaVgA3M...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            50 non-null     object
#  1   album_name          50 non-null     object
#  2   album_release_date  50 non-null     object
#  3   album_total_tracks  50 non-null     int64
#  4   album_url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %% [markdown]
# #### Dropping the duplicates off the df

# %%
album_df = album_df.drop_duplicates(subset =['album_id'])

# %% [markdown]
# ### ARTIST DF

# %%
artist_df = pd.DataFrame.from_dict(artist_list)
artist_df.head()
# Out:
#                 artist_id    artist_name  \
# 0  22wbnEMDvgVIAGdFeek6ET   Benson Boone
# 1  6vWDO969PvNqNYHIOW5v0m        Beyoncé
# 2  4xPQFgDA5M2xa0ZGo5iIsv             ¥$
# 3  5K4W6rqBFWDnAN6FQUkS6x     Kanye West
# 4  7c0XG5cIJTrrAgEC3ULPiq  Ty Dolla $ign
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/22wbnEMDvgV...
# 1  https://api.spotify.com/v1/artists/6vWDO969PvN...
# 2  https://api.spotify.com/v1/artists/4xPQFgDA5M2...
# 3  https://api.spotify.com/v1/artists/5K4W6rqBFWD...
# 4  https://api.spotify.com/v1/artists/7c0XG5cIJTr...

# %%
artist_df = artist_df.drop_duplicates(subset =['artist_id'])

# %% [markdown]
# ### SONG DF

# %%
song_df = pd.DataFrame.from_dict(song_list)
song_df.head()
# Out:
#                   song_id         song_name  duration_ms  \
# 0  6tNQ70jh4OwmPGpYy6R2o9  Beautiful Things       180304
# 1  7AYmToZ5y67fBjq4RLFbuq    TEXAS HOLD 'EM       235636
# 2  3w0w2T288dec0mgeZZqoNN          CARNIVAL       264324
# 3  3rUGC1vUpkDG9CZFHMur1t            greedy       131872
# 4  1BxfuPKGuaTgP7aM0Bbdwr      Cruel Summer       178426
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/6tNQ70jh4OwmPGp...          98
# 1  https://open.spotify.com/track/7AYmToZ5y67fBjq...          77
# 2  https://open.spotify.com/track/3w0w2T288dec0mg...          88
# 3  https://open.spotify.com/track/3rUGC1vUpkDG9CZ...         100
# 4  https://open.spotify.com/track/1BxfuPKGuaTgP7a...          99
#
#              song_added                album_id               artist_id
# 0  2024-02-22T10:08:45Z  29aSKB1qPEbN0Qf9OPSQpw  22wbnEMDvgVIAGdFeek6ET
# 1  2024-02-22T10:08:45Z  2NXwHjhgaAdkDy6GPSxMAd  6vWDO969PvNqNYHIOW5v0m
# ...

# %%
song_df = song_df.drop_duplicates(subset =['song_id'])

# %% [markdown]
# #### Converting to datetime format

# %%
album_df['album_release_date'] = pd.to_datetime(album_df['album_release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            50 non-null     object
#  1   album_name          50 non-null     object
#  2   album_release_date  50 non-null     datetime64[ns]
#  3   album_total_tracks  50 non-null     int64
#  4   album_url           50 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.1+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.3+ KB
